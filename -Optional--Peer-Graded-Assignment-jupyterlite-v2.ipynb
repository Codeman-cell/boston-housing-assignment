# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Import the required libraries we need for the lab.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# #### Read the dataset in the csv file from the URL

# %%
boston_df=pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv')

# %% [markdown]
# #### Add your code below following the instructions given in the course to complete the peer graded assignment

# %%
# Question 1: Boxplot for MEDV vs CHAS (Charles River)
sns.boxplot(x='CHAS', y='MEDV', data=boston_df)
pyplot.title("Median Value of Houses vs Charles River")
pyplot.show()


# Question 2: Histogram for MEDV (Median value of owner-occupied homes)
pyplot.hist(boston_df['MEDV'], bins=20)
pyplot.title("Distribution of Median Value of Homes")
pyplot.xlabel("MEDV")
pyplot.ylabel("Frequency")
pyplot.show()


# Question 3: Scatter plot for NOX vs INDUS
sns.scatterplot(x='INDUS', y='NOX', data=boston_df)
pyplot.title("NOX vs INDUS")
pyplot.show()


# Question 4: T-test for MEDV vs CHAS
river = boston_df[boston_df['CHAS'] == 1]['MEDV']
no_river = boston_df[boston_df['CHAS'] == 0]['MEDV']

t_stat, p_value = scipy.stats.ttest_ind(river, no_river)

print("T-test results:")
print("t-statistic =", t_stat)
print("p-value =", p_value)


# Question 5: ANOVA for MEDV vs AGE groups
# Create age groups
boston_df['AGE_GROUP'] = pd.cut(boston_df['AGE'],
                               bins=[0, 35, 70, 100],
                               labels=['Young', 'Middle', 'Old'])

model = ols('MEDV ~ C(AGE_GROUP)', data=boston_df).fit()
anova_results = sm.stats.anova_lm(model, typ=2)

print("\nANOVA results:")
print(anova_results)
